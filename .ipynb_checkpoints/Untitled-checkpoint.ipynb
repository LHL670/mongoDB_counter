# %%
import datetime
import queue
import pymongo
from pymongo import MongoClient
cluster = MongoClient("mongodb+srv://CGUScholar:cguscholarpwd@cluster0.hvf4e.mongodb.net/myFirstDatabase?retryWrites=true&w=majority")
db = cluster["CGUScholar"]

# %%
# update = '2022-05-07 12:33:06'
def currentDate():
    currentTime = datetime.datetime.now()
    currentDate = currentTime.date().strftime("%Y-%m-%d")
    return currentDate
def check_ifupdate(update_date, current_date):
    #change datetime type
    update_date = datetime.datetime.strptime(update_date, "%Y-%m-%d %H:%M:%S")
    update_date = update_date.date()
    #Whether to update today
    if update_date == current_date:
        return True
    else:
        return False

# %%
import json


def jsontransform(items):
    data = json.dumps(items)
    jsonStr = json.loads(data)
    return jsonStr

# %%
# #  personalDatadict = jsonTransfer.jsontransform(personalData)
# labelname = "Chemical_Physics"
# # def update_userIDinlabellength()
# if db.Statistical_data.count_documents({"_id":labelname}, limit=1) != 0:
#     print('exist')
#     a = {"$push": {'countRecord': {"$each": [todayrecord_]}}}
    
#     db.Statistical_data.update_one({"_id":labelname}, a)
# else:
#     db.Statistical_data.insert_one({"_id":labelname}, a)
#     print('None')

# #         print(str(personalDatadict['_id'])+" exist")
# #         a = {"$push": {'citedRecord': {
# #             "$each": personalDatadict['citedRecord']}}}
# #         b = {"$set": {
# #             'updateTime': personalDatadict['updateTime'], 'cited': personalDatadict['cited']}}
# #         ab = merge_two_dicts(a, b)
# #         # print(ab)
# #         db.cguscholar.update_one({'_id': personalDatadict['_id']}, ab)
# #     else:
# #         print(str(personalDatadict['_id'])+" not found")
# #         db.cguscholar.insert_one(personalDatadict)

# %%
# db = cluster["CGUScholar"]
# list(db.Statistical_data.find({'Statistical_data': { '$elemMatch': { 'label':labelname} } }))

# %%
db = cluster["CGUScholar"]
def count_userIDinlabel(currentDate):
    print(currentDate)    
    getlabelname = list(db.Label_Domain.find({"updateTime": {"$regex": currentDate}}).limit(10))
    for label in getlabelname:
        print(label['_id'])
        todayrecord = {}
        userIDlength = len(label['userID'])
        todayrecord['updateTime'] = currentDate
        todayrecord['userIDcount'] = userIDlength
        insertrecord = {'$push': {'countRecord': {'$each': [todayrecord]}}}
        if db.Statistical_data.count_documents({'_id':label['_id']}, limit=1) != 0:
            print(label['_id'] + ' update ' + todayrecord['userIDcount'])            
    
            db.Statistical_data.update_one({'_id':label['_id']}, insertrecord)
        else:
            db.Statistical_data.insert_one({'_id':label['_id']}, insertrecord)
            print(label['_id'] + ' insert ' + todayrecord['userIDcount'])  
            
        
        
        
#     try:
#             # label has been crawled
#         getlabelname = db.Label_Domain.find({"updateTime": {"$gt":{"$ne": None}}}).count
# #             labelname = getlabelname['_id']

#             # check labelname format
# #             if '-' in labelname or ' ' in labelname:
# #                 adjust_labelname(labelname)
# #                 continue

# #             labelcount = labelcount + 1

# #             labelnameQueue.put(labelname)
#     except:
#         continue
    return len(getlabelname)

# %%
# !pip3 install schedule
# Out:
# ...
#   Using cached schedule-1.1.0-py2.py3-none-any.whl (10 kB)
# ...

# %%
from pymongo import MongoClient
from getTime import currentDate
import schedule
import time
cluster = MongoClient(
    "mongodb+srv://CGUScholar:cguscholarpwd@cluster0.hvf4e.mongodb.net/myFirstDatabase?retryWrites=true&w=majority")
db = cluster["CGUScholar"]


def count_userIDinlabel():
    print('start userID in label counter')
    today = "2022-04-30"
    print(today)
    getlabelname = list(db.Label_Domain.find(
        {"updateTime": {"$regex": today}}).limit(100))
    for label in getlabelname:
        todayrecord = {}
        userIDlength = len(label['userID'])
        if userIDlength == 0:
            continue
        todayrecord['updateTime'] = today
        todayrecord['userIDcount'] = userIDlength
        insertrecord = {'$push': {'countRecord': {'$each': [todayrecord]}}}
        if db.Statistical_data.count_documents({'_id': label['_id']}, limit=1) != 0:
            print(label['_id'] + ' update ' + str(todayrecord['userIDcount']))

            db.Statistical_data.update_one({'_id': label['_id']}, insertrecord)
        else:
            db.Statistical_data.insert_one({'_id': label['_id']}, insertrecord)
            print(label['_id'] + ' insert ' + str(todayrecord['userIDcount']))


schedule.every().day.at("23:20").do(count_userIDinlabel())
if __name__ == '__main__':
    while 1:
        schedule.run_pending()
        time.sleep(1)
# Out:
# start userID in label counter
# 2022-04-30
# Plasma_Spectroscopy update 64
# Microwave_imaging update 198
# UHV_systems update 2
# Aluminizing update 4
# Plasma_Propulsion update 19
# Cryogenics update 350
# Materials_Processing update 286
# Liquid_Metals update 83
# Chemical_Physics update 683
# learning_sciences update 503
# instructional_technology update 579
# crisis_management update 365
# dance_medicine update 14
# applied_thermodynamics update 105
# Learning_theory update 355
# scholarship_of_engagement update 4
# Emerging_Instructional_Technology update 1
# formative_assessment update 115
# Environmental_systems_analysis update 29
# biology_education update 638
# evidence_based_practice update 461
# vocational_education update 483
# civic_engagement update 306
# Professional_Identity_Formation update 14
# Medical_and_Health_Professions_Education update 6
# patient_eductation update 1
# Accreditation update 153
# Electrical_Engineering_Technology update 1
# ...

# %%
count_userIDinlabel("2022-04-30")
# Out:
# 2022-04-30
# Plasma_Spectroscopy
# {'$push': {'countRecord': {'$each': [{'updateTime': '2022-04-30', 'userIDcount': 64}]}}} exist
# Microwave_imaging
# {'$push': {'countRecord': {'$each': [{'updateTime': '2022-04-30', 'userIDcount': 198}]}}} exist
# UHV_systems
# {'$push': {'countRecord': {'$each': [{'updateTime': '2022-04-30', 'userIDcount': 2}]}}} exist
# Aluminizing
# {'$push': {'countRecord': {'$each': [{'updateTime': '2022-04-30', 'userIDcount': 4}]}}} exist
# Plasma_Propulsion
# {'$push': {'countRecord': {'$each': [{'updateTime': '2022-04-30', 'userIDcount': 19}]}}} exist
# Cryogenics
# {'$push': {'countRecord': {'$each': [{'updateTime': '2022-04-30', 'userIDcount': 350}]}}} exist
# Materials_Processing
# {'$push': {'countRecord': {'$each': [{'updateTime': '2022-04-30', 'userIDcount': 286}]}}} exist
# Liquid_Metals
# {'$push': {'countRecord': {'$each': [{'updateTime': '2022-04-30', 'userIDcount': 83}]}}} exist
# Chemical_Physics
# ...
